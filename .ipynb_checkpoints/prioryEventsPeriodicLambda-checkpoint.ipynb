# %%
# %run prioryEventsPeriodicLambda/prioryEventsPeriodicLambda.py
if __name__ == "__main__":
    prioryEventsPeriodicLambda(None, None)
# Out:
# Downloaded calendar from website.
# Got 2 applicable calendar events.
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-1-432089caeb4f> in <module>
#       3 RUN_CODE_LOCAL = True
#       4 if __name__ == "__main__":
# ----> 5     prioryEventsPeriodicLambda(None, None)
#       6
#
# ~/Documents/python/PrioryAlexa/prioryEventsPeriodicLambda/prioryEventsPeriodicLambda.py in prioryEventsPeriodicLambda(event, context)
#     245     print(f"Got {len(events)} applicable calendar events.")
#     246     pd = PopulateDynamoDBEventTable(events)
# --> 247     pd.populate_dynamoDB()
#     248     print("Populated DynamoDB")
#
# ~/Documents/python/PrioryAlexa/prioryEventsPeriodicLambda/prioryEventsPeriodicLambda.py in populate_dynamoDB(self)
#     226         with table.batch_writer() as batch:
#     227             for event in self.events:
# --> 228                 batch.put_item(Item=event)
#     229
#     230         # We need to delete entries in DynamoDB that are no longer present
#
# ~/miniconda3/lib/python3.7/site-packages/boto3/dynamodb/table.py in __exit__(self, exc_type, exc_value, tb)
#     154         # until there's nothing left in our items buffer.
#     155         while self._items_buffer:
# --> 156             self._flush()
#
# ~/miniconda3/lib/python3.7/site-packages/boto3/dynamodb/table.py in _flush(self)
#     135         self._items_buffer = self._items_buffer[self._flush_amount:]
#     136         response = self._client.batch_write_item(
# --> 137             RequestItems={self._table_name: items_to_send})
#     138         unprocessed_items = response['UnprocessedItems']
#     139
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     611         else:
#     612             http, parsed_response = self._make_request(
# --> 613                 operation_model, request_dict, request_context)
#     614
#     615         self.meta.events.emit(
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     630     def _make_request(self, operation_model, request_dict, request_context):
#     631         try:
# --> 632             return self._endpoint.make_request(operation_model, request_dict)
#     633         except Exception as e:
#     634             self.meta.events.emit(
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     130     def _send_request(self, request_dict, operation_model):
#     131         attempts = 1
# --> 132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/endpoint.py in create_request(self, params, operation_model)
#     114                 op_name=operation_model.name)
#     115             self._event_emitter.emit(event_name, request=request,
# --> 116                                      operation_name=operation_model.name)
#     117         prepared_request = self.prepare_request(request)
#     118         return prepared_request
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     354     def emit(self, event_name, **kwargs):
#     355         aliased_event_name = self._alias_event_name(event_name)
# --> 356         return self._emitter.emit(aliased_event_name, **kwargs)
#     357
#     358     def emit_until_response(self, event_name, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      88         # this method is invoked to sign the request.
#      89         # Don't call this method directly.
# ---> 90         return self.sign(operation_name, request)
#      91
#      92     def sign(self, operation_name, request, region_name=None,
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     158                     raise e
#     159
# --> 160             auth.add_auth(request)
#     161
#     162     def _choose_signer(self, operation_name, signing_type, context):
#
# ~/miniconda3/lib/python3.7/site-packages/botocore/auth.py in add_auth(self, request)
#     355     def add_auth(self, request):
#     356         if self.credentials is None:
# --> 357             raise NoCredentialsError
#     358         datetime_now = datetime.datetime.utcnow()
#     359         request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
